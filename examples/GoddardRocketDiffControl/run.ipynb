# %%
import matplotlib.pyplot as plt
from pymaverick import spline
from pymaverick import solver as slv

# %%
mf = 4539
m0 = 12500

model_parameters = {
    'g' : 9.81,
    'c' : 1715,
    'sigma' : 0.0665,
    'h0' : 90000,

    #mass
    'mi' : m0,
    'mmin' : 0.8*mf,
    'mmax' : 1.2*m0,
    'mguess' : mf,

    # speed
    'Vi' : 0,
    'Vmin' : -1500,
    'Vmax' : 1500,
    'Vguess' : 300,

    #height
    'hi' : 0,
    'hmin' : 0,
    'hmax' : 200000,

    #Control
    'Fmin' : 0,
    'Fmax' : 1.9*9.81*m0,

    # time
    'Tmin' : 0,
    'Tmax' : 500,
    'Tguess' : 100,

    # target
    'wl1' : 0,
    'wm' : 1,
    'wlt' : 0,
    'wl2' : 1e-16, # to suppress oscillations: does not affect results at least up to 1e-5
}

# %%
solver_data = {
    'info_level' : 4,

    'Model' : {

        'Parameters' : model_parameters,

        'Scaling' : {
            'Phase0' : {
                'target' : 100,
                'states_and_controls' : "automatic-bounds", # V, h ,m,F
                'parameters' : "automatic-bounds", # T
                'fo_equations' : [20, 500, 60 ], # automatic bounds is not allowed for equations
                'boundary_conditions' : [500, 5000, 7000],
            },
        },

    },

    'Mesh' : {
        'max_iterations' : 10,
        'tolerance' : 1e-9,
        'Phase0' : {
           'Segments' : [ {'length' : 1, 'num_points' : 50} ],
        },
    },

    'Solver' : {
        'max_iterations' : 300,
        'nlp_solver' : "Ipopt",
        'IpoptOptions' : {
            'linear_solver' : "ma27",
            'ma57_automatic_scaling' : "yes",
            'mu_strategy' : "adaptive",
            'check_derivatives_for_naninf' : "yes",
        },
    },
}

# %%
solver = slv.Solver('./sources/libGoddardRocket.so')

# %%
output = solver.solve(solver_data)
sol = output['solution']['Phase0']
# Out:
# Setting up ocp problem ...
# Setting up ocp problem ...
# OCP model parameters detail:
#    Vmin   -1.500000e+03
#    Vmax    1.500000e+03
#      Vi    0.000000e+00
#  Vguess    3.000000e+02
#    hmin    0.000000e+00
#    hmax    2.000000e+05
#      hi    0.000000e+00
#    mmin    3.631200e+03
#    mmax    1.500000e+04
#      mi    1.250000e+04
#  mguess    4.539000e+03
#    Tmin    0.000000e+00
#    Tmax    5.000000e+02
#  Tguess    1.000000e+02
#    Fmin    0.000000e+00
#    Fmax    2.329875e+05
#      h0    9.000000e+04
#   sigma    6.650000e-02
#       c    1.715000e+03
#       g    9.810000e+00
#     wl1    0.000000e+00
#     wl2    1.000000e-16
#      wm    1.000000e+00
#     wlt    0.000000e+00
#
# Setting up mesh ...
# Setting up nlp scaling ...
# Scaling factors details:
# Phase0
# 	target: 100
# 	states and controls: 3000, 200000, 11368.8, 232988,
# 	parameters: 500,
# 	first order equations: 20, 500, 60,
# 	boundary_conditions: 500, 5000, 7000,
# scaling options:
# 	multiply_lagrange_by_n.............false
# 	multiply_int_constr_by_n...........false
# 	multiply_foeqns_by_dz..............false
# 	multiply_foeqns_by_n...............false
# 	divide_foeqns_by_z.................false
# 	multiply_path_constr_by_dz.........false
# 	multiply_path_constr_by_n..........false
# 	divide_path_constr_by_z............false
# 	multiply_point_constr_by_dz........false
# 	multiply_point_constr_by_n.........false
# 	divide_point_constr_by_z...........false
# 	divide_mayer_by_n..................false
# 	divide_bcs_by_n....................false
#
# Setting up nlp solver...
# Using guess from ocp problem ...
# Start solving the problem ...
#
# This is Ipopt version 3.14.4, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      934
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:
#
#
# Number of objective function evaluations             = 31
# Number of objective gradient evaluations             = 27
# Number of equality constraint evaluations            = 31
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 27
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 26
# Total seconds in IPOPT                               = 0.078
#
# EXIT: Optimal Solution Found.
#
# Computation time: 0.079488s
# Mesh error is NOT satisfied in current mesh (iteration 0) : 1.944101e-04 (threshold = 1.000000e-09)
# Setting up mesh ...
# Using warm guess with multipliers ...
# Start solving the problem ...
#
# This is Ipopt version 3.14.4, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     5247
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     6637
#
# Total number of variables............................:     1109
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1109
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      831
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.9739210e+02 1.01e+00 7.25e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -7.9748256e+02 4.33e-01 3.10e-01  -4.0 2.06e-01    -  7.72e-01 5.73e-01h  1
#    2 -7.9721174e+02 7.77e-02 5.54e-02  -4.3 5.39e-01    -  9.74e-01 8.20e-01h  1
#    3 -7.9727383e+02 1.21e-02 1.25e-02  -5.0 1.46e-01    -  9.50e-01 8.44e-01h  1
#    4 -7.9731884e+02 1.99e-03 2.33e-02  -5.6 7.82e-02    -  9.85e-01 8.35e-01h  1
#    5 -7.9733883e+02 1.51e-04 6.01e-03  -6.9 3.28e-02    -  9.97e-01 9.24e-01h  1
#    6 -7.9734108e+02 1.79e-05 3.21e-03  -7.9 1.81e-02    -  1.00e+00 9.53e-01h  1
#    7 -7.9734125e+02 2.52e-06 1.13e-03  -9.4 1.06e-02    -  1.00e+00 9.75e-01h  1
#    8 -7.9734126e+02 3.11e-07 1.44e-04  -9.7 4.41e-03    -  1.00e+00 1.00e+00h  1
#    9 -7.9734126e+02 2.10e-08 7.42e-08 -10.4 1.15e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -7.9734126e+02 1.67e-10 2.59e-10 -10.9 1.02e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.9867062937829218e+01   -7.9734125875658435e+02
# Dual infeasibility......:   2.5897036465492854e-10    5.1794072930985711e-09
# Constraint violation....:   6.2485092889744204e-11    1.6675105740659999e-10
# Variable bound violation:   9.9943776588062860e-09    9.9943776588062860e-09
# Complementarity.........:   2.3149131765587715e-11    4.6298263531175428e-10
# Overall NLP error.......:   2.5897036465492854e-10    5.1794072930985711e-09
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total seconds in IPOPT                               = 0.069
#
# EXIT: Optimal Solution Found.
#
# Computation time: 0.070845s
# Mesh error is NOT satisfied in current mesh (iteration 1) : 1.875329e-06 (threshold = 1.000000e-09)
# Setting up mesh ...
# Using warm guess with multipliers ...
# Start solving the problem ...
#
# This is Ipopt version 3.14.4, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    13835
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    17485
#
# Total number of variables............................:     2917
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     2917
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2187
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.9734122e+02 6.36e-01 3.48e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -7.9742625e+02 2.11e-01 9.58e-02  -4.6 4.52e-02    -  9.64e-01 6.69e-01h  1
#    2 -7.9735180e+02 1.46e-02 5.03e-03  -5.5 2.75e-02    -  9.79e-01 9.31e-01h  1
#    3 -7.9733672e+02 2.42e-03 1.12e-03  -6.4 3.91e-02    -  8.13e-01 8.34e-01h  1
#    4 -7.9733888e+02 2.15e-04 4.43e-04  -7.6 1.71e-02    -  8.63e-01 9.11e-01h  1
#    5 -7.9733936e+02 3.30e-05 2.49e-03  -8.3 1.06e-02    -  9.88e-01 8.46e-01h  1
#    6 -7.9733949e+02 4.13e-06 2.09e-03  -9.1 7.37e-03    -  1.00e+00 8.75e-01h  1
#    7 -7.9733952e+02 4.02e-07 7.69e-04 -10.1 2.88e-03    -  1.00e+00 9.33e-01h  1
#    8 -7.9733952e+02 6.76e-09 3.60e-04 -10.6 1.05e-03    -  1.00e+00 9.89e-01h  1
#    9 -7.9733952e+02 5.79e-10 2.61e-08 -11.0 3.36e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -7.9733952e+02 1.19e-11 3.18e-09 -11.0 4.83e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.9866976089312161e+01   -7.9733952178624315e+02
# Dual infeasibility......:   3.1785790676797135e-09    6.3571581353594272e-08
# Constraint violation....:   1.4874308846061746e-12    1.1871037486343994e-11
# Variable bound violation:   9.9894601479633138e-09    9.9894601479633138e-09
# Complementarity.........:   1.3079513707190722e-11    2.6159027414381441e-10
# Overall NLP error.......:   3.1785790676797135e-09    6.3571581353594272e-08
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total seconds in IPOPT                               = 0.061
#
# EXIT: Optimal Solution Found.
#
# Computation time: 0.065084s
# Mesh error is NOT satisfied in current mesh (iteration 2) : 3.685040e-08 (threshold = 1.000000e-09)
# Setting up mesh ...
# Using warm guess with multipliers ...
# Start solving the problem ...
#
# This is Ipopt version 3.14.4, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    16039
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    20269
#
# Total number of variables............................:     3381
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     3381
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2535
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.9733952e+02 6.08e-01 2.65e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -7.9749207e+02 1.62e-01 7.72e-02  -4.8 2.78e-02    -  9.73e-01 7.34e-01h  1
#    2 -7.9736137e+02 5.34e-03 1.21e-03  -6.2 1.54e-02    -  9.27e-01 9.67e-01h  1
#    3 -7.9733995e+02 2.59e-04 1.15e-03  -7.4 1.70e-02    -  7.42e-01 9.51e-01h  1
#    4 -7.9733928e+02 1.06e-04 5.30e-02  -7.3 1.03e-02    -  9.95e-01 5.90e-01h  1
#    5 -7.9733939e+02 1.31e-05 1.41e-02  -8.0 1.47e-02    -  1.00e+00 8.77e-01h  1
#    6 -7.9733954e+02 4.52e-06 2.12e-03  -9.0 1.02e-02    -  1.00e+00 9.63e-01h  1
#    7 -7.9733954e+02 1.35e-06 3.69e-01  -8.9 3.03e-03    -  1.00e+00 7.32e-01h  1
#    8 -7.9733956e+02 7.48e-08 1.23e-02  -9.7 1.29e-03    -  1.00e+00 9.73e-01h  1
#    9 -7.9733956e+02 1.48e-09 8.12e-03 -10.3 2.96e-04    -  1.00e+00 9.89e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -7.9733956e+02 2.64e-11 3.70e-04 -11.0 6.54e-05    -  1.00e+00 9.99e-01h  1
#   11 -7.9733956e+02 5.77e-13 2.37e-10 -11.0 2.36e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 11
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.9866977979703478e+01   -7.9733955959406956e+02
# Dual infeasibility......:   2.3668786337847608e-10    4.7337572675695213e-09
# Constraint violation....:   1.8264866409644639e-14    5.7729529659999363e-13
# Variable bound violation:   9.9897713989882675e-09    9.9897713989882675e-09
# Complementarity.........:   1.4451694276904059e-11    2.8903388553808117e-10
# Overall NLP error.......:   2.3668786337847608e-10    4.7337572675695213e-09
#
#
# Number of objective function evaluations             = 12
# Number of objective gradient evaluations             = 12
# Number of equality constraint evaluations            = 12
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 12
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 11
# Total seconds in IPOPT                               = 0.059
#
# EXIT: Optimal Solution Found.
#
# Computation time: 0.062768s
# Mesh error is NOT satisfied in current mesh (iteration 3) : 1.731124e-09 (threshold = 1.000000e-09)
# Setting up mesh ...
# Using warm guess with multipliers ...
# Start solving the problem ...
#
# This is Ipopt version 3.14.4, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    16153
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    20413
#
# Total number of variables............................:     3405
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     3405
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2553
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.9733956e+02 6.07e-01 2.65e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -7.9767408e+02 7.11e-02 3.42e-02  -5.2 1.87e-02    -  9.73e-01 8.83e-01h  1
#    2 -7.9736341e+02 5.52e-03 2.55e-03  -6.5 1.14e-02    -  9.26e-01 9.22e-01h  1
#    3 -7.9734099e+02 4.10e-04 3.62e-04  -7.5 1.37e-02    -  8.48e-01 9.26e-01h  1
#    4 -7.9733961e+02 2.52e-05 2.40e-04  -8.5 9.73e-03    -  9.77e-01 9.38e-01h  1
#    5 -7.9733957e+02 5.71e-06 5.56e-03  -9.1 9.84e-03    -  1.00e+00 7.73e-01h  1
#    6 -7.9733956e+02 1.95e-06 4.05e-02  -9.0 4.91e-03    -  1.00e+00 6.59e-01h  1
#    7 -7.9733956e+02 1.37e-07 1.49e-03 -10.0 2.01e-03    -  1.00e+00 9.76e-01h  1
#    8 -7.9733956e+02 3.09e-09 8.04e-04 -10.6 2.44e-04    -  1.00e+00 9.85e-01h  1
#    9 -7.9733956e+02 4.39e-12 1.79e-10 -11.0 1.47e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.9866978169796205e+01   -7.9733956339592407e+02
# Dual infeasibility......:   1.7855461659685043e-10    3.5710923319370086e-09
# Constraint violation....:   1.1021949074975505e-13    4.3930192816787897e-12
# Variable bound violation:   9.9890625215870443e-09    9.9890625215870443e-09
# Complementarity.........:   1.2446020999286159e-11    2.4892041998572319e-10
# Overall NLP error.......:   1.7855461659685043e-10    3.5710923319370086e-09
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total seconds in IPOPT                               = 0.044
#
# EXIT: Optimal Solution Found.
#
# Computation time: 0.048015s
# Mesh error is NOT satisfied in current mesh (iteration 4) : 1.195427e-09 (threshold = 1.000000e-09)
# Setting up mesh ...
# Using warm guess with multipliers ...
# Start solving the problem ...
#
# This is Ipopt version 3.14.4, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    16172
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    20437
#
# Total number of variables............................:     3409
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     3409
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2556
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.9733957e+02 6.07e-01 2.65e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -7.9769851e+02 4.29e-02 2.15e-02  -5.2 1.69e-02    -  9.75e-01 9.30e-01h  1
#    2 -7.9734299e+02 4.63e-04 3.11e-04 -10.5 1.02e-02    -  8.70e-01 9.89e-01h  1
#    3 -7.9734205e+02 3.76e-04 1.33e-01  -7.0 1.48e-02    -  9.64e-01 1.89e-01h  1
#    4 -7.9733933e+02 1.74e-05 8.37e-03  -7.6 1.00e-02    -  1.00e+00 9.53e-01h  1
#    5 -7.9733947e+02 2.67e-06 2.30e-02  -8.3 9.05e-03    -  1.00e+00 8.46e-01h  1
#    6 -7.9733953e+02 1.01e-06 2.31e-02  -8.7 5.53e-03    -  1.00e+00 9.43e-01h  1
#    7 -7.9733956e+02 6.61e-08 1.37e-07  -9.6 1.64e-03    -  1.00e+00 1.00e+00h  1
#    8 -7.9733956e+02 9.96e-09 1.13e-01 -10.8 2.89e-04    -  1.00e+00 8.68e-01h  1
#    9 -7.9733956e+02 3.97e-11 2.01e-09 -10.8 4.62e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.9866978196438779e+01   -7.9733956392877553e+02
# Dual infeasibility......:   2.0104666013081668e-09    4.0209332026163339e-08
# Constraint violation....:   9.9499518755706289e-13    3.9657432893136504e-11
# Variable bound violation:   9.9852511259435062e-09    9.9852511259435062e-09
# Complementarity.........:   2.8004056592386871e-11    5.6008113184773740e-10
# Overall NLP error.......:   2.0104666013081668e-09    4.0209332026163339e-08
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total seconds in IPOPT                               = 0.059
#
# EXIT: Optimal Solution Found.

# %%
plt.figure()
plt.plot(sol['t'],sol['thrust']);
plt.xlabel('time [s]')
plt.ylabel('thrust [N]')
plt.grid(True)

# %%
plt.figure()
plt.plot(sol['t'],sol['h'])
plt.xlabel('time [s]')
plt.ylabel('height [m]')
plt.grid(True)

# %%
plt.figure()
plt.plot(sol['t'], sol['V'])
plt.xlabel('time [s]')
plt.ylabel('speed [m/s]')
plt.grid(True)
